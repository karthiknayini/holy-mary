# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
dataset=pd.read_csv(r"C:\Users\teju\Downloads\1569582940_googleplaystore\googleplaystore.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
dataset.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
dataset=dataset.dropna()

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   object
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1023.8+ KB

# %%
dataset['Installs']=dataset.Installs.str.replace('+','').str.replace(',','')
# Out:
# <ipython-input-82-ae6168df5460>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   dataset['Installs']=dataset.Installs.str.replace('+','').str.replace(',','')

# %%
dataset['Installs']=dataset.Installs.astype(int)

# %%
dataset['Price']=dataset.Price.str.replace('$','')
# Out:
# <ipython-input-84-a98f9253da85>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   dataset['Price']=dataset.Price.str.replace('$','')

# %%
dataset['Price']=dataset.Price.astype(float)

# %%
dataset['Reviews']=dataset.Reviews.str.replace('M','')

# %%
dataset['Reviews']=dataset.Reviews.astype(float)

# %%
dataset
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
def fix_size(y):
    if 'M' in y:
        
        x=y[:-1]
        x=float(x)*1000
        return x
    elif 'K' in y:
        
        x=y[:-1]
        x=float(x)
        return x
    else:
        return None
dataset['Size']=dataset['Size'].apply(fix_size)
dataset
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
dataset.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating               0
# Reviews              0
# Size              1894
# Installs             0
# Type                 0
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          0
# Android Ver          0
# dtype: int64

# %%
dataset=dataset.dropna()

# %%
dataset[(1>dataset.Rating)|(dataset.Rating>5)]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
dataset[(dataset['Reviews']) >(dataset['Installs'])]
# Out:
#                         App Category  Rating  Reviews     Size  Installs  \
# 2454    KBA-EZ Health Guide  MEDICAL     5.0      4.0  25000.0         1
# 5917               Ra Ga Ba     GAME     5.0      2.0  20000.0         1
# 6700       Brick Breaker BR     GAME     5.0      7.0  19000.0         5
# 7402   Trovami se ci riesci     GAME     5.0     11.0   6100.0        10
# 8591                DN Blog   SOCIAL     5.0     20.0   4200.0        10
# 10697               Mu.F.O.     GAME     5.0      2.0  16000.0         1
#
#        Type  Price Content Rating   Genres      Last Updated Current Ver  \
# 2454   Free   0.00       Everyone  Medical    August 2, 2018      1.0.72
# 5917   Paid   1.49       Everyone   Arcade  February 8, 2017       1.0.4
# 6700   Free   0.00       Everyone   Arcade     July 23, 2018         1.0
# 7402   Free   0.00       Everyone   Arcade    March 11, 2017         0.1
# 8591   Free   0.00           Teen   Social     July 23, 2018         1.0
# ...

# %%
dataset.drop([2454,5917,7402,8591,6700,10697],axis=0,inplace=True)
# Out:
# C:\Users\teju\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dataset[(dataset.Type=='Free')&(dataset.Price>0)]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
sns.boxplot(data = dataset,y ='Price');

# %%
sns.boxplot(data = dataset,y ='Reviews');

# %%
sns.histplot(data=dataset,x='Rating')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %%
sns.histplot(data=dataset,x='Size')
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Count'>

# %%
dataset[dataset.Price>200]
# Out:
#                                  App   Category  Rating  Reviews     Size  \
# 4197          most expensive app (H)     FAMILY     4.3      6.0   1500.0
# 4362                      💎 I'm rich  LIFESTYLE     3.8    718.0  26000.0
# 4367        I'm Rich - Trump Edition  LIFESTYLE     3.6    275.0   7300.0
# 5351                       I am rich  LIFESTYLE     3.8   3547.0   1800.0
# 5354                  I am Rich Plus     FAMILY     4.0    856.0   8700.0
# 5355                   I am rich VIP  LIFESTYLE     3.8    411.0   2600.0
# 5356               I Am Rich Premium    FINANCE     4.1   1867.0   4700.0
# 5357             I am extremely Rich  LIFESTYLE     2.9     41.0   2900.0
# 5358                      I am Rich!    FINANCE     3.8     93.0  22000.0
# 5362                   I Am Rich Pro     FAMILY     4.4    201.0   2700.0
# 5364  I am rich (Most expensive app)    FINANCE     4.1    129.0   2700.0
# 5366                       I Am Rich     FAMILY     3.6    217.0   4900.0
# ...

# %%
dataset.drop([5373,5369,5366,5364,5362,5358,5357,5356,5355,5354,5351,4367,4362,4197],inplace=True)
# Out:
# C:\Users\teju\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dataset[dataset.Reviews>2000000]
# Out:
#                                                App       Category  Rating  \
# 345                    Yahoo Mail – Stay Organized  COMMUNICATION     4.3
# 347                  imo free video calls and chat  COMMUNICATION     4.3
# 366    UC Browser Mini -Tiny Fast Private & Secure  COMMUNICATION     4.4
# 378    UC Browser - Fast Download Private & Secure  COMMUNICATION     4.5
# 383                  imo free video calls and chat  COMMUNICATION     4.3
# ...                                            ...            ...     ...
# 9142                     Need for Speed™ No Limits           GAME     4.4
# 9166                  Modern Combat 5: eSports FPS           GAME     4.3
# 10186                             Farm Heroes Saga         FAMILY     4.4
# 10190                              Fallout Shelter         FAMILY     4.6
# 10327                             Garena Free Fire           GAME     4.5
#
#           Reviews     Size   Installs  Type  Price Content Rating  \
# ...

# %%
count=dataset[(dataset['Reviews']>2000000)].index
dataset.drop(count,inplace=True)
# Out:
# C:\Users\teju\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
Q1 = np.percentile(dataset.Installs, 10)
Q2 = np.percentile(dataset.Installs, 25)
Q3 = np.percentile(dataset.Installs, 50)
Q4 = np.percentile(dataset.Installs, 75)
Q5 = np.percentile(dataset.Installs, 90)
Q6 = np.percentile(dataset.Installs, 95)
Q7 = np.percentile(dataset.Installs, 99)

# %%
Q1
Q2
Q3
Q4
Q5
Q6
Q7
# Out:
# 1000.0
# 10000.0
# 100000.0
# 1000000.0
# 10000000.0
# 10000000.0
# 50000000.0

# %%
count=dataset[(dataset['Installs']>1000000)].index
dataset.drop(count,inplace=True)
# Out:
# C:\Users\teju\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
dataset
# Out:
#                                                   App             Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                 Coloring book moana       ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                          Paper flowers instructions       ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# ...                                               ...                  ...
# 10829                  Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                               News Minecraft.fr   NEWS_AND_MAGAZINES
# 10834                                   FR Calculator               FAMILY
# 10836                                Sya9a Maroc - FR               FAMILY
# 10837                Fr. Mike Schmitz Audio Teachings               FAMILY
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=dataset,x='Rating',y='Price')
# high rating apps have high price
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Price'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=dataset,x='Rating',y='Size')
#heavier apps have more rating
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Size'>

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=dataset,x='Rating',y='Reviews')
# yes mostly more review means better rating always
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Reviews'>

# %%
plt.figure(figsize=(10,10))

sns.boxplot(data=dataset,y='Rating',x='Content Rating')
#all types are same rating but Everyine & Mature 17+ have more outliers
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='Rating'>

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=dataset,x='Rating',y='Category')
#education has best rating
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Category'>

# %%
inp1=dataset.copy()

# %%
inp1
# Out:
#                                                   App             Category  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                 Coloring book moana       ART_AND_DESIGN
# 4               Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                          Paper flowers instructions       ART_AND_DESIGN
# 6             Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# ...                                               ...                  ...
# 10829                  Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                               News Minecraft.fr   NEWS_AND_MAGAZINES
# 10834                                   FR Calculator               FAMILY
# 10836                                Sya9a Maroc - FR               FAMILY
# 10837                Fr. Mike Schmitz Audio Teachings               FAMILY
#
# ...

# %% [raw]
# we are performig log transformation on reviews and installs

# %%
inp1["Reviews"]=np.log1p(dataset["Reviews"])
inp1["Installs"]=np.log1p(dataset["Installs"])

# %%
inp1.drop(["App","Last Updated","Current Ver","Android Ver"],axis=1,inplace=True)

# %%
inp2=pd.get_dummies(inp1)

# %%
inp2
# Out:
#        Rating   Reviews     Size   Installs  Price  Category_ART_AND_DESIGN  \
# 0         4.1  5.075174  19000.0   9.210440    0.0                        1
# 1         3.9  6.875232  14000.0  13.122365    0.0                        1
# 4         4.3  6.875232   2800.0  11.512935    0.0                        1
# 5         4.4  5.123964   5600.0  10.819798    0.0                        1
# 6         3.8  5.187386  19000.0  10.819798    0.0                        1
# ...       ...       ...      ...        ...    ...                      ...
# 10829     4.6  6.403574   7400.0   9.210440    0.0                        0
# 10830     3.8  6.782192   2300.0  11.512935    0.0                        0
# 10834     4.0  2.079442   2600.0   6.216606    0.0                        0
# 10836     4.5  3.663562  53000.0   8.517393    0.0                        0
# 10837     5.0  1.609438   3600.0   4.615121    0.0                        0
#
#        Category_AUTO_AND_VEHICLES  Category_BEAUTY  \
# ...

# %%
x=inp2.drop(['Rating'],axis=1) # independent variable
y=inp2[['Rating']] # dependent variable

# %%
x
# Out:
#         Reviews     Size   Installs  Price  Category_ART_AND_DESIGN  \
# 0      5.075174  19000.0   9.210440    0.0                        1
# 1      6.875232  14000.0  13.122365    0.0                        1
# 4      6.875232   2800.0  11.512935    0.0                        1
# 5      5.123964   5600.0  10.819798    0.0                        1
# 6      5.187386  19000.0  10.819798    0.0                        1
# ...         ...      ...        ...    ...                      ...
# 10829  6.403574   7400.0   9.210440    0.0                        0
# 10830  6.782192   2300.0  11.512935    0.0                        0
# 10834  2.079442   2600.0   6.216606    0.0                        0
# 10836  3.663562  53000.0   8.517393    0.0                        0
# 10837  1.609438   3600.0   4.615121    0.0                        0
#
#        Category_AUTO_AND_VEHICLES  Category_BEAUTY  \
# 0                               0                0
# ...

# %%
y
# Out:
#        Rating
# 0         4.1
# 1         3.9
# 4         4.3
# 5         4.4
# 6         3.8
# ...       ...
# 10829     4.6
# 10830     3.8
# 10834     4.0
# 10836     4.5
# 10837     5.0
#
# [5710 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
Linear_reg= LinearRegression()

# %%
Linear_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_pred=Linear_reg.predict(x_test)

# %%
x_pred
# Out:
# array([[4.30742555],
#        [3.95466534],
#        [4.0109038 ],
#        ...,
#        [4.21558177],
#        [4.20889076],
#        [3.94160968]])

# %%
y_test
# Out:
#        Rating
# 1301      4.0
# 7419      4.0
# 10014     4.5
# 6772      4.8
# 7869      4.3
# ...       ...
# 7905      4.6
# 2427      5.0
# 1349      4.3
# 7700      3.8
# 2353      4.6
#
# [1713 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
print('MSE=',mean_squared_error(y_test,x_pred))
# Out:
# MSE= 0.3253535425866057

# %%
print('RMSE=',np.sqrt(mean_squared_error(y_test,x_pred)))
# Out:
# RMSE= 0.5703977056288058

# %%
import joblib
joblib.dump(Linear_reg,"linear_model.sav")
# Out:
# ['linear_model.sav']
